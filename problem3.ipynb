# %%
import librosa, librosa.display 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import noisereduce as nr

# %%
librosa.version.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# python: 3.7.10 | packaged by conda-forge | (default, Feb 19 2021, 15:37:01) [MSC v.1916 64 bit (AMD64)]
#
# librosa: 0.8.1
#
# audioread: 2.1.9
# numpy: 1.20.3
# scipy: 1.7.3
# sklearn: 1.0.2
# joblib: 1.1.0
# decorator: 5.1.0
# soundfile: 0.10.3
# resampy: 0.2.2
# numba: 0.54.1
#
# numpydoc: None
# sphinx: 4.5.0
# sphinx_rtd_theme: None
# sphinxcontrib.versioning: None
# sphinx-gallery: None
# pytest: None
# pytest-mpl: None
# pytest-cov: None
# matplotlib: 3.4.3
# presets: None

# %%
audio_path = "./P3/문제3-1.wav"
sig1,sr = librosa.load(audio_path,sr=32000)
sig1 = nr.reduce_noise(y=sig1, sr=sr)

audio_path = "./P3/문제3-2.wav"
sig2,sr = librosa.load(audio_path,sr=32000)
sig2 = nr.reduce_noise(y=sig2, sr=sr)

audio_path = "./P3/문제3-3.wav"
sig3,sr = librosa.load(audio_path,sr=32000)
sig3 = nr.reduce_noise(y=sig3, sr=sr)

sig1
# Out:
# array([ 2.4456088e-09,  3.1514419e-10, -1.3229676e-09, ...,
#         7.2293647e-06,  7.2388525e-06,  4.7884937e-06], dtype=float32)

# %%
print("음성 1 길이 : {}".format(len(sig1)/32000))
print("음성 2 길이 : {}".format(len(sig2)/32000))
print("음성 3 길이 : {}".format(len(sig3)/32000))
# Out:
# 음성 1 길이 : 3.36
# 음성 2 길이 : 3.36
# 음성 3 길이 : 3.24

# %% [markdown]
# # 시각화

# %%
FIG_SIZE = (15,10)
plt.figure(figsize=FIG_SIZE)
sig1_pre = np.diff(sig1)
sig1_pre = (sig1_pre-sig1_pre.mean())/sig1_pre.std()
librosa.display.waveplot(sig1_pre, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (db)")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
for i in range(len(sig1_pre)):
    if np.abs(sig1_pre)[i:i+500].sum()>120:
        print(i)
# Out:
# 25224
# 25225
# 25226
# 25227
# 25228
# 25229
# 25230
# 25231
# 25232
# 25233
# 25234
# 25235
# 25236
# 25237
# 25238
# 25239
# 25240
# 25241
# 25242
# 25243
# 25244
# 25245
# 25246
# 25247
# 25248
# 25249
# 25250
# 25251
# 25252
# 25253
# 25254
# 25255
# 25256
# 25257
# 25258
# 25259
# 25260
# 25261
# 25262
# 25263
# 25264
# 25265
# 25266
# 25267
# 25268
# 25269
# 25270
# 25271
# 25272
# 25273
# 25274
# 25275
# 25276
# 25277
# 25278
# 25279
# 25280
# 25281
# 25282
# 25283
# 25284
# 25285
# 25286
# 25287
# 25288
# 25289
# 25290
# 25291
# 25292
# 25293
# 25294
# 25295
# 25296
# 25297
# 25298
# 25299
# 25300
# 25301
# 25302
# 25303
# 25304
# 25305
# 25306
# 25307
# 25308
# 25309
# 25310
# 25311
# 25312
# 25313
# 25314
# 25315
# 25316
# 25317
# 25318
# 25319
# 25320
# 25321
# 25322
# 25323
# 25324
# 25325
# 25326
# 25327
# 25328
# 25329
# 25330
# 25331
# 25332
# 25333
# 25334
# 25335
# 25336
# 25337
# 25338
# 25339
# 25340
# 25341
# 25342
# 25343
# 25344
# 25345
# 25346
# 25347
# 25348
# ...

# %%
sig1_pre=sig1_pre[::-1]

# %%
for i in range(len(sig1_pre)):
    if np.abs(sig1_pre)[i:i+500].sum()>120:
        print(len(sig1_pre)-i)
# Out:
# 90632
# 90631
# 90630
# 90629
# 90628
# 90272
# 90268
# 90267
# 90266
# 90265
# 90264
# 90263
# 90262
# 90261
# 90260
# 90259
# 90258
# 90257
# 90256
# 90255
# 90254
# 90253
# 90252
# 90251
# 90250
# 90249
# 90248
# 90247
# 90246
# 90245
# 90244
# 90243
# 90242
# 90241
# 90240
# 90239
# 90238
# 90237
# 90236
# 90235
# 90234
# 90233
# 90232
# 90231
# 90230
# 90229
# 90228
# 90227
# 90226
# 90225
# 90224
# 90223
# 90222
# 90221
# 90220
# 90219
# 90218
# 90217
# 90216
# 90215
# 90214
# 90213
# 90212
# 90211
# 90210
# 90209
# 90208
# 90207
# 90206
# 90205
# 90204
# 90203
# 90202
# 90201
# 90200
# 90199
# 90198
# 90197
# 90196
# 90195
# 90194
# 90193
# 90192
# 90191
# 90190
# 90189
# 90188
# 90187
# 90186
# 90185
# 90184
# 90183
# 90182
# 90181
# 90180
# 90179
# 90178
# 90177
# 87054
# 87053
# 87052
# 87051
# 87050
# 87049
# 87048
# 87047
# 87041
# 87040
# 87039
# 87038
# 87037
# 87032
# 87031
# 87030
# 87029
# 87028
# 87027
# 87026
# 87025
# 87024
# 86727
# 86726
# 86725
# 86718
# 86717
# ...

# %%
FIG_SIZE = (15,10)
plt.figure(figsize=FIG_SIZE)

sig2_pre = np.diff(sig2)
sig2_pre = (sig2_pre-sig2_pre.mean())/sig2_pre.std()
librosa.display.waveplot(sig2_pre, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (db)")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
for i in range(len(sig2_pre)):
    if np.abs(sig2_pre)[i:i+500].sum()>120:
        print(i)
# Out:
# 25200
# 25201
# 25202
# 25203
# 25204
# 25205
# 25206
# 25207
# 25208
# 25209
# 25210
# 25211
# 25212
# 25213
# 25214
# 25215
# 25216
# 25217
# 25218
# 25221
# 25223
# 25224
# 25225
# 25226
# 25227
# 25228
# 25229
# 25230
# 25231
# 25232
# 25233
# 25234
# 25235
# 25236
# 25237
# 25238
# 25239
# 25240
# 25241
# 25242
# 25243
# 25244
# 25245
# 25246
# 25247
# 25248
# 25249
# 25250
# 25251
# 25252
# 25253
# 25254
# 25255
# 25256
# 25257
# 25258
# 25259
# 25260
# 25261
# 25262
# 25263
# 25264
# 25265
# 25266
# 25267
# 25268
# 25269
# 25270
# 25271
# 25272
# 25273
# 25274
# 25275
# 25276
# 25277
# 25278
# 25279
# 25280
# 25281
# 25282
# 25283
# 25284
# 25285
# 25286
# 25287
# 25288
# 25289
# 25290
# 25291
# 25292
# 25293
# 25294
# 25295
# 25296
# 25297
# 25298
# 25299
# 25300
# 25301
# 25302
# 25303
# 25304
# 25305
# 25306
# 25307
# 25308
# 25309
# 25310
# 25311
# 25312
# 25313
# 25314
# 25315
# 25316
# 25317
# 25318
# 25319
# 25320
# 25321
# 25322
# 25323
# 25324
# 25325
# 25326
# 25327
# ...

# %%
sig2_pre=sig2_pre[::-1]

# %%
for i in range(len(sig2_pre)):
    if np.abs(sig2_pre)[i:i+500].sum()>120:
        print(len(sig2_pre)-i)
# Out:
# 90273
# 90272
# 90271
# 90270
# 90269
# 90268
# 90267
# 90266
# 90265
# 90264
# 90263
# 90262
# 90261
# 90260
# 90259
# 90258
# 90257
# 90256
# 90255
# 90254
# 90253
# 90252
# 90251
# 90250
# 90249
# 90248
# 90247
# 90246
# 90245
# 90244
# 90243
# 90242
# 90241
# 90240
# 90239
# 90238
# 90237
# 90236
# 90235
# 90234
# 90233
# 90232
# 90231
# 90230
# 90229
# 90228
# 90227
# 90226
# 90225
# 90224
# 90223
# 90222
# 90221
# 90220
# 90219
# 90218
# 90217
# 90216
# 90215
# 90214
# 90213
# 90212
# 90211
# 90210
# 90209
# 90208
# 90207
# 90206
# 90205
# 90204
# 90203
# 90202
# 90201
# 90200
# 90199
# 90198
# 90197
# 90196
# 90195
# 90194
# 90193
# 90192
# 90191
# 90190
# 90189
# 90188
# 90187
# 90186
# 90185
# 90184
# 90183
# 90182
# 90181
# 90180
# 90179
# 90178
# 90177
# 82865
# 82864
# 82863
# 82862
# 82861
# 82860
# 82859
# 82858
# 82857
# 82856
# 82855
# 82854
# 82853
# 82852
# 82851
# 82850
# 82849
# 82848
# 82847
# 82846
# 82845
# 82844
# 82843
# 82842
# 82841
# 82840
# 82839
# 82838
# ...

# %%
FIG_SIZE = (15,10)
plt.figure(figsize=FIG_SIZE)
sig3_pre = np.diff(sig3)
sig3_pre = (sig3_pre-sig3_pre.mean())/sig3_pre.std()
librosa.display.waveplot(sig3_pre, sr, alpha=0.5)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (db)")
plt.title("Waveform")
# Out:
# Text(0.5, 1.0, 'Waveform')

# %%
for i in range(len(sig3_pre)):
    if np.abs(sig3_pre)[i:i+500].sum()>120:
        print(i)
# Out:
# 22838
# 22839
# 22840
# 22841
# 22842
# 22843
# 22844
# 22845
# 22846
# 22847
# 22848
# 22849
# 22850
# 22851
# 22852
# 22853
# 22854
# 22855
# 22856
# 22857
# 22858
# 22859
# 22860
# 22861
# 22862
# 22863
# 22864
# 22865
# 22866
# 22867
# 22868
# 22869
# 22870
# 22871
# 22872
# 22873
# 22874
# 22875
# 22876
# 22877
# 22878
# 22879
# 22880
# 22881
# 22882
# 22883
# 22884
# 22885
# 22886
# 22887
# 22888
# 22889
# 22890
# 22891
# 22892
# 22893
# 22894
# 22895
# 22896
# 22897
# 22898
# 22899
# 22900
# 22901
# 22902
# 22903
# 22904
# 22905
# 22906
# 22907
# 22908
# 22909
# 22910
# 22911
# 22912
# 22913
# 22914
# 22915
# 22916
# 22917
# 22918
# 22919
# 22920
# 22921
# 22922
# 22923
# 22924
# 22925
# 22926
# 22927
# 22928
# 22929
# 22930
# 22931
# 22932
# 22933
# 22934
# 22935
# 22936
# 22937
# 22938
# 22939
# 22940
# 22941
# 22942
# 22943
# 22944
# 22945
# 22946
# 22947
# 22948
# 22949
# 22950
# 22951
# 22952
# 22953
# 22954
# 22955
# 22956
# 22957
# 22958
# 22959
# 22960
# 22961
# 22962
# ...

# %%
sig3_pre[::-1]
# Out:
# array([ 0.27472103, -0.12379873, -0.2657556 , ..., -0.11337402,
#        -1.2194309 , -0.7734996 ], dtype=float32)

# %%
sig3_pre=sig3_pre[::-1]
for i in range(len(sig3_pre)):
    if np.abs(sig3_pre)[i:i+50].sum()>32:
        print(len(sig3_pre)-i)
# Out:
# 80378
# 80377
# 80376
# 80375
# 80374
# 80373
# 80372
# 80371
# 80370
# 80369
# 80368
# 80367
# 80366
# 80365
# 80364
# 80363
# 80362
# 80361
# 80360
# 80359
# 80358
# 80357
# 80356
# 80355
# 80354
# 80353
# 80352
# 80351
# 80350
# 80349
# 80348
# 80347
# 80346
# 80345
# 80344
# 80343
# 80342
# 80341
# 80340
# 80339
# 80338
# 80337
# 80336
# 80335
# 80334
# 80333
# 80332
# 80331
# 80330
# 80329
# 80006
# 80005
# 80004
# 80003
# 80002
# 80001
# 80000
# 79999
# 79998
# 79997
# 79996
# 79995
# 79994
# 79993
# 79992
# 79991
# 79990
# 79989
# 79988
# 79987
# 79986
# 79985
# 79984
# 79983
# 79982
# 79981
# 79980
# 79979
# 79978
# 79977
# 79976
# 79975
# 79974
# 79973
# 79972
# 79971
# 79970
# 79969
# 79968
# 79967
# 79966
# 79965
# 79964
# 79963
# 79962
# 79961
# 79960
# 79959
# 79958
# 79957
# 79956
# 79955
# 79954
# 79953
# 79952
# 79951
# 79950
# 79949
# 79948
# 79947
# 79946
# 79945
# 79944
# 79943
# 79942
# 79941
# 79940
# 79939
# 79938
# 79937
# 79936
# 79935
# 79934
# 79933
# 79932
# ...

# %%
win_length =  np.int64(16000/40) # 1250
n_fft = win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length = np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다. (stride)
#hop: 윈도우가 겹치는 사이즈

stfts=librosa.stft(sig1,win_length=win_length,n_fft=n_fft, hop_length=hop_length)
plt.figure(figsize=FIG_SIZE)
magnitude = np.abs(stfts)
log_spectrogram = librosa.amplitude_to_db(magnitude)
librosa.display.specshow(log_spectrogram, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
np.abs( np.diff( log_spectrogram[10:,1:].mean(axis=0) ) )
# Out:
# array([5.88976669e+00, 1.32474899e-01, 5.48915863e-02, 2.27590561e-01,
#        2.02701569e-01, 2.32175827e-01, 1.56894684e-01, 4.96826172e-02,
#        6.39514923e-02, 4.40425873e-02, 6.33792877e-02, 1.36985779e-01,
#        1.35345459e-02, 4.38861847e-02, 9.46674347e-02, 1.06128693e-01,
#        8.81462097e-02, 1.19800568e-02, 1.17950439e-02, 1.10645294e-02,
#        2.62069702e-03, 7.64083862e-03, 1.08613968e-01, 1.58309937e-02,
#        3.62758636e-02, 2.41584778e-02, 6.34307861e-02, 3.83281708e-02,
#        6.29138947e-02, 9.06181335e-03, 1.11253738e-01, 4.22954559e-02,
#        1.96075439e-02, 1.08192444e-01, 6.46896362e-02, 1.81064606e-02,
#        1.06254578e-01, 9.57107544e-03, 1.08638763e-01, 1.19934082e-02,
#        9.29718018e-02, 8.21132660e-02, 3.19290161e-02, 3.09944153e-02,
#        2.37655640e-03, 2.11715698e-03, 4.60815430e-02, 4.33425903e-02,
#        2.93540955e-03, 1.71070099e-02, 7.85999298e-02, 6.67572021e-05,
# ...

# %%
np.abs( np.diff( log_spectrogram[100:,1:].mean(axis=0) ) ) <2
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False, False,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
win_length =  np.int64(16000/40) # 1250
n_fft = win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length = np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다. (stride)
#hop: 윈도우가 겹치는 사이즈

stfts=librosa.stft(sig2,win_length=win_length,n_fft=n_fft, hop_length=hop_length)
plt.figure(figsize=FIG_SIZE)
magnitude = np.abs(stfts)
log_spectrogram = librosa.amplitude_to_db(magnitude)
librosa.display.specshow(log_spectrogram[10:128,1:], sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
np.abs( np.diff( log_spectrogram.mean(axis=0) ) ) <1
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False, False, False, False,
#         True, False,  True, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
# win_length =  np.int64(16000/40) # 1250
n_fft = win_length # WINDOWS SIZE중 사용할 길이. WINDOW SIZE가 넘어가면 나머지 것들은 zero padding
hop_length = np.int64( np.ceil(win_length/4) ) #  얼마만큼 시간 주기를 이동하면서 분석을 할 것인지. 일반적으로 window size의 1/4
#또는 10ms만큼으로 한다고 한다. (stride)
#hop: 윈도우가 겹치는 사이즈

stfts=librosa.stft(sig3,win_length=win_length,n_fft=n_fft, hop_length=hop_length)
plt.figure(figsize=FIG_SIZE)
magnitude = np.abs(stfts)
log_spectrogram = librosa.amplitude_to_db(magnitude)
librosa.display.specshow(log_spectrogram, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format='%+2.0f dB')
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
np.abs( np.diff( log_spectrogram[100:,1:].mean(axis=0) ) ) < 1
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
mel_feature = librosa.feature.melspectrogram(sig3,sr=sr,hop_length=hop_length,n_fft=n_fft)
mel_feature = librosa.core.power_to_db(mel_feature,ref=np.max)
librosa.display.specshow(mel_feature, sr=sr, hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')

# %%
mel_feature[32:,:].sum(axis=0)
# Out:
# array([-7548.6763, -7617.926 , -7637.6924, -7631.946 , -7580.698 ,
#        -7572.2485, -7504.1865, -7449.0957, -7369.284 , -7291.2427,
#        -7222.305 , -7259.7744, -7391.8623, -7475.0156, -7471.0747,
#        -7479.3037, -7520.45  , -7508.3926, -7544.3467, -7580.092 ,
#        -7580.3496, -7591.6377, -7614.0547, -7611.65  , -7614.5376,
#        -7630.2446, -7626.994 , -7612.1006, -7615.5107, -7629.691 ,
#        -7629.8784, -7632.4575, -7631.3003, -7631.5996, -7619.127 ,
#        -7616.8066, -7605.5537, -7593.895 , -7563.1045, -7522.283 ,
#        -7492.314 , -7479.7896, -7518.0454, -7501.9546, -7525.8677,
#        -7516.795 , -7533.6147, -7576.987 , -7601.1133, -7577.509 ,
#        -7622.7227, -7650.6855, -7634.209 , -7617.3057, -7632.3555,
#        -7648.707 , -7615.207 , -7554.2896, -7562.878 , -7569.066 ,
#        -7601.0264, -7607.792 , -7634.841 , -7665.5264, -7675.104 ,
#        -7674.4907, -7647.3525, -7669.5557, -7680.    , -7680.    ,
# ...

# %%
MFCCs = librosa.feature.mfcc(sig3, sr,win_length=win_length ,n_fft=n_fft, hop_length=hop_length, n_mfcc=13)

# display MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sr, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")

# show plots
plt.show()
print(MFCCs.shape)
# 497 frame(time step).
# 497 frame 만큼 RNN에서 시점을 가진다.
# Out:
# (13, 519)

# %%
MFCCs.sum(axis=0)
# Out:
# array([ 9.90572834e+00,  1.14947975e+02,  4.84234161e+01,  5.96713867e+01,
#         4.62503548e+01,  1.00637535e+02,  6.44674377e+01,  6.27291756e+01,
#         2.97767925e+01,  3.06508312e+01,  3.00858383e+01,  5.88684540e+01,
#         3.69941101e+01,  2.23503761e+01, -1.65011654e+01, -9.06193352e+00,
#         4.71773338e+00,  1.13737869e+00, -2.40284195e+01,  3.95117784e+00,
#         4.90442734e+01,  4.79416733e+01, -1.34573183e+01,  2.46342602e+01,
#         3.16038208e+01,  1.93769417e+01,  8.98620224e+00, -1.62900829e+00,
#        -5.49343071e+01, -7.19186478e+01, -2.09202156e+01, -2.70973930e+01,
#        -3.68149414e+01,  2.28886414e+00,  3.38021183e+00, -6.20124435e+00,
#        -4.50691910e+01,  1.34985809e+01,  2.78239441e+01,  2.51068115e-01,
#        -5.21471024e+00, -2.79637356e+01, -6.80692387e+00, -2.12386589e+01,
#        -1.97867985e+01, -3.61628418e+01, -3.59656677e+01, -7.25453339e+01,
# ...

# %% [markdown]
# # pass filter

# %%
from scipy.io import wavfile
from scipy import signal
import os

# %%
low_pass=signal.firwin(101,cutoff=500,fs=sr,pass_zero='lowpass')
x1 = signal.filter(b,[1.0],x)
# Out:
# array([-1.94599983e-04, -1.02379424e-04,  2.03433173e-19,  1.16287442e-04,
#         2.49732447e-04,  4.02246986e-04,  5.73596018e-04,  7.60694017e-04,
#         9.57082233e-04,  1.15265320e-03,  1.33367545e-03,  1.48315315e-03,
#         1.58153387e-03,  1.60775319e-03,  1.54058034e-03,  1.36020455e-03,
#         1.04998021e-03,  5.98230944e-04, -8.37165077e-19, -7.41371826e-04,
#        -1.61295891e-03, -2.59136417e-03, -3.64232768e-03, -4.72090319e-03,
#        -5.77224738e-03, -6.73303457e-03, -7.53347508e-03, -8.09987972e-03,
#        -8.35767916e-03, -8.23477565e-03, -7.66507934e-03, -6.59206249e-03,
#        -4.97215439e-03, -2.77779830e-03,  1.91320667e-18,  3.34978541e-03,
#         7.23855497e-03,  1.16115409e-02,  1.63929277e-02,  2.14875137e-02,
#         2.67832776e-02,  3.21547719e-02,  3.74672144e-02,  4.25811198e-02,
#         4.73572774e-02,  5.16618645e-02,  5.53714706e-02,  5.83778102e-02,
# ...

# %%
plt.plot(low_pass)
